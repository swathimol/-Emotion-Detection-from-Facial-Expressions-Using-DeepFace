# %%
import cv2 #computer vision

# %%
img=cv2.imread("/content/girll.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #bgr

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) #RGB

# %%
# !pip install deepface

# %%
from deepface import DeepFace
pred=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s]

# %%
type(pred)
pred
# Out:
# [{'emotion': {'angry': 2.5164855656485028e-17,
#    'disgust': 1.9685215841808058e-28,
#    'fear': 1.0776005563000245e-19,
#    'happy': 99.99680519104004,
#    'sad': 1.2085556893356303e-11,
#    'surprise': 3.900149517579998e-11,
#    'neutral': 0.003199923230567947},
#   'dominant_emotion': 'happy',
#   'region': {'x': 234,
#    'y': 102,
#    'w': 120,
#    'h': 120,
#    'left_eye': (312, 149),
#    'right_eye': (271, 154)},
#   'face_confidence': 0.92,
#   'age': 19,
#   'gender': {'Woman': 22.544284164905548, 'Man': 77.4557113647461},
#   'dominant_gender': 'Man',
#   'race': {'asian': 15.222810208797455,
#    'indian': 13.152796030044556,
#    'black': 21.566319465637207,
#    'white': 1.574544981122017,
#    'middle eastern': 0.7221680600196123,
#    'latino hispanic': 47.761356830596924},
#   'dominant_race': 'latino hispanic'}]

# %%
prediction=pred[0]
prediction["dominant_emotion"]
# Out:
# 'happy'
